# %% [markdown]
# <a href="https://colab.research.google.com/github/fakhreldin001/egypt-property-ai/blob/main/egypt_property_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import google drive library
from google.colab import drive

#connect google drive to this notebook
drive.mount('/content/drive')

#create project folder in drive
# !mkdir -p "/content/drive/My Drive/egypt-property-ai"

#change workingdirectory to the new folder
# %cd "/content/drive/My Drive/egypt-property-ai"

#confirmation message
print("Connected to Google Drive Successfully!")

#show current path
current_path = !pwd
print("Current Path : " , current_path[0])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/egypt-property-ai
# Connected to Google Drive Successfully
# Current Path :  /content/drive/My Drive/egypt-property-ai

# %%
#install required libraries
# !pip install -q pandas matplotlib seaborn supabase python-dotenv scikit-learn requests beautifulsoup4
print(" All Packages Installed Successfully!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 7.6 MB/s eta 0:00:00
#  All Packages Installed Successfully!

# %%
#create .env file to store sensitive data
# %%writefile .env
SUPABASE_URL=https://wvoggelqantxesjxsgtj.supabase.co
SUPABASE_KEY=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Ind2b2dnZWxxYW50eGVzanhzZ3RqIiwicm9sZSI6ImFub24iLCJpYXQiOjE3Njg5NTc1MzksImV4cCI6MjA4NDUzMzUzOX0.EGFRaLvPwJMr9OwU8nZmWY4P6YSd3hMpRF1VnyG1OFw
ENVIRONMENT=development
# Out:
# Overwriting .env

# %%
#import required libraries
import os
from dotenv import load_dotenv
from supabase import create_client , Client
load_dotenv()

#real url and key from .env file
SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_KEY = os.getenv("SUPABASE_KEY")

#verify if data exists
if not SUPABASE_URL or not SUPABASE_KEY:
  print("Error : Check your .env file")
else:
  #connet to database
  supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)
  print("Connected to Supabase Successfully!")
  print(f"Supabase URL : {SUPABASE_URL[:30]}...")
# Out:
# Connected to Supabase Successfully!
# Supabase URL : https://wvoggelqantxesjxsgtj.s...

# %%
#verify properties table exists

#reading the data from the table
try:
  response = supabase.table('properties').select("*").limit(1).execute()
  print("Properties table exists and workwing!")
  # Only print the number of columns if there is data to avoid IndexError
  if response.data:
    print(f" Number of columns: {len(response.data[0].keys())}")

  if len(response.data) == 0:
    print("Table is empty (its okay we havent added data yet)")
  else:
    print("First row :")
    print(response.data[0])
except Exception as e:
  print(f"Error : {e}")
  print("\n Solution:")
  print("make sure you made supabase dashboard in sql")
  print("make sure url and key are in .env")
# Out:
# Properties table exists and workwing!
# Table is empty (its okay we havent added data yet)
