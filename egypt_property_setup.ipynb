# %% [markdown]
# <a href="https://colab.research.google.com/github/fakhreldin001/egypt-property-ai/blob/main/egypt_property_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Create project folder in Drive
# !mkdir -p "/content/drive/MyDrive/egypt-property-ai"
# %cd "/content/drive/MyDrive/egypt-property-ai"

import os
print("Connected to Google Drive")
print(f"Working directory: {os.getcwd()}")
# Out:
# /content/drive/MyDrive/egypt-property-ai
# Connected to Google Drive
# Working directory: /content/drive/MyDrive/egypt-property-ai

# %%
#Install required packages
# !pip install -q pandas scikit-learn matplotlib seaborn sqlalchemy fastapi python-dotenv
print("Packages installed successfully!")
# Out:
# Packages installed successfully!
